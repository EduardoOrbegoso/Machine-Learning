# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df= pd.read_csv('./boletos.csv')
df.head()
# Out:
#    years  boleto
# 0     66    8.17
# 1     65    8.13
# 2     64    7.96
# 3     63    7.93
# 4     62    7.89

# %%
x = df['years']
y = df['boleto']

x1 = df['years']
y1 = df['boleto']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train = x_train.values.reshape([x_train.values.shape[0],1])
x_test = x_test.values.reshape([x_test.values.shape[0],1])

# %%
titles = ['Grado 0','Grado 1','Grado 2','Grado 3','Grado 4','Grado 5','Grado 6']
colores = ['teal','pink','hotpink','orchid','aqua','green','blue']

# %%
for i in range(1,7):
  poly = PolynomialFeatures(degree=i)
  x_poly = poly.fit_transform(x_train)
  xt_poly = poly.fit_transform(x_test)
  poly_model = LinearRegression()
  poly_model.fit(x_poly,y_train)
  pred = poly_model.predict(x_poly)
  pred2 = poly_model.predict(xt_poly)
  xt,yt = zip(*sorted(zip(x_test,pred2)))
  x,y = zip(*sorted(zip(x_train,pred)))
  
  plt.subplot(2,3,i)
  plt.plot(x,y,'-',color=colores[i],label=titles[i],markersize=2)
  plt.plot(xt,yt,'+',color='turquoise',markersize=5)
  plt.plot(x1,y1,'*',color='crimson',markersize=.5)
  plt.legend(loc=2)
